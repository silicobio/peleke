# %% [markdown]
# # INTERCAAT Tests

# %%
# !python -m pip install pyhull
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyhull: filename=pyhull-2015.2.1-cp312-cp312-macosx_10_9_x86_64.whl size=193581 sha256=bf27be7b65d7da66ca295d3e5faaa0562bc8af249ae709ae44eb3005cd566e05
#   Stored in directory: /private/var/folders/__/1v5xyw5s0tl2z88yrm0lb4d40000gn/T/pip-ephem-wheel-cache-u164apbi/wheels/f4/f5/3a/b61e2fa2b618f779bbdb9e71a9f7e6916dbc9f05c3bab358c4
# Successfully built pyhull
# ...

# %%
# !python intercaat/intercaat.py -pdb 1cph.pdb -qc B -ic A -fp ./intercaat
# Out:
# Res #   Interactions
#   Query Chain    |Interacting Chains| Dist | AtomClasses

# %%
## Load Libraries
from intercaat.interface import InterfaceAnalyzer

# %%
analyzer = InterfaceAnalyzer('1cph.pdb', 'B', ['A'], path = './intercaat')
analyzer.get_interface_residues()
# Out:
# []
